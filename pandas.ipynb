# %% [markdown]
# ## Pandas Learning Notebook
# created by Minhyeok Park <pmh_only@pmh.codes>

# %%
# %pip install -r requirements.txt

import pandas as pd
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('./winemag-data-130k-v2.csv')
df.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.shape
# Out:
# (65499, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df[['country', 'taster_name']]
# Out:
#          country         taster_name
# 0          Italy       Kerin O’Keefe
# 1       Portugal          Roger Voss
# 2             US        Paul Gregutt
# 3             US  Alexander Peartree
# 4             US        Paul Gregutt
# ...          ...                 ...
# 65494     France          Roger Voss
# 65495  Australia      Joe Czerwinski
# 65496         US                 NaN
# 65497         US                 NaN
# 65498      Spain   Michael Schachner
#
# [65499 rows x 2 columns]

# %%
df['country'].unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia'],
#       dtype=object)

# %%
df[df['country'] == "Italy"].head(5)
# Out:
#     Unnamed: 0 country                                        description  \
# 0            0   Italy  Aromas include tropical fruit, broom, brimston...
# 6            6   Italy  Here's a bright, informal red that opens with ...
# 13          13   Italy  This is dominated by oak and oak-driven aromas...
# 22          22   Italy  Delicate aromas recall white flower and citrus...
# 24          24   Italy  Aromas of prune, blackcurrant, toast and oak c...
#
#      designation  points  price           province  region_1 region_2  \
# 0   Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 6        Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# 13         Rosso      87    NaN  Sicily & Sardinia      Etna      NaN
# 22     Ficiligno      87   19.0  Sicily & Sardinia   Sicilia      NaN
# 24         Aynat      87   35.0  Sicily & Sardinia   Sicilia      NaN
#
#       taster_name taster_twitter_handle  \
# 0   Kerin O’Keefe          @kerinokeefe
# ...

# %%
df2 = df.copy()
df2.loc[df2['country'] == "Italy", 'country'] = 'a'
df2.to_csv('./sample2.csv')

df2.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0         a  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df[df['price'] < 10].head()
# Out:
#      Unnamed: 0  country                                        description  \
# 42           42   France  This is a festive wine, with soft, ripe fruit ...
# 44           44    Chile  A berry aroma comes with cola and herb notes. ...
# 76           76  Germany  Earthy pollen and mineral notes lend a savory ...
# 240         240   France  Dominated by Ugni Blanc, the grape also used i...
# 306         306  Romania  Fragrant on the nose with fresh orange, lemon ...
#
#     designation  points  price          province  \
# 42      Nouveau      86    9.0        Beaujolais
# 44          NaN      86    9.0      Maule Valley
# 76          NaN      86    9.0       Rheinhessen
# 240         NaN      85    9.0  Southwest France
# 306         NaN      87    7.0             Recas
#
#                               region_1 region_2         taster_name  \
# 42                          Beaujolais      NaN          Roger Voss
# 44                                 NaN      NaN   Michael Schachner
# ...

# %%
df[(df['price'] < 10) & (df['price'] > 5)].head()
# Out:
#      Unnamed: 0  country                                        description  \
# 42           42   France  This is a festive wine, with soft, ripe fruit ...
# 44           44    Chile  A berry aroma comes with cola and herb notes. ...
# 76           76  Germany  Earthy pollen and mineral notes lend a savory ...
# 240         240   France  Dominated by Ugni Blanc, the grape also used i...
# 306         306  Romania  Fragrant on the nose with fresh orange, lemon ...
#
#     designation  points  price          province  \
# 42      Nouveau      86    9.0        Beaujolais
# 44          NaN      86    9.0      Maule Valley
# 76          NaN      86    9.0       Rheinhessen
# 240         NaN      85    9.0  Southwest France
# 306         NaN      87    7.0             Recas
#
#                               region_1 region_2         taster_name  \
# 42                          Beaujolais      NaN          Roger Voss
# 44                                 NaN      NaN   Michael Schachner
# ...

# %%
df[df['country'].isin(['Italy', 'France'])].head()
# Out:
#     Unnamed: 0 country                                        description  \
# 0            0   Italy  Aromas include tropical fruit, broom, brimston...
# 6            6   Italy  Here's a bright, informal red that opens with ...
# 7            7  France  This dry and restrained wine offers spice in p...
# 9            9  France  This has great depth of flavor with its fresh ...
# 11          11  France  This is a dry wine, very spicy, with a tight, ...
#
#      designation  points  price           province  region_1 region_2  \
# 0   Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 6        Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# 7            NaN      87   24.0             Alsace    Alsace      NaN
# 9    Les Natures      87   27.0             Alsace    Alsace      NaN
# 11           NaN      87   30.0             Alsace    Alsace      NaN
#
#       taster_name taster_twitter_handle  \
# 0   Kerin O’Keefe          @kerinokeefe
# ...

# %%
df[df['price'].notnull()].head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# ...

# %%
max_point = df['points'].max()
df['points'].map(lambda p: p / max_point * 100)

df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df['prov-county'] = df['country'] + '-' + df['province']
df[['country', 'province', 'prov-county']].head()
# Out:
#     country           province              prov-county
# 0     Italy  Sicily & Sardinia  Italy-Sicily & Sardinia
# 1  Portugal              Douro           Portugal-Douro
# 2        US             Oregon                US-Oregon
# 3        US           Michigan              US-Michigan
# 4        US             Oregon                US-Oregon

# %%
df.groupby('country')['points'].count().sort_values(ascending=False)
# Out:
# country
# US                        27177
# France                    11174
# Italy                     10005
# Spain                      3409
# Portugal                   2963
# Chile                      2258
# Argentina                  1907
# Austria                    1635
# Australia                  1177
# Germany                    1051
# South Africa                737
# New Zealand                 733
# Israel                      259
# Greece                      242
# Canada                      108
# Bulgaria                     68
# Romania                      67
# Hungary                      61
# Uruguay                      61
# Croatia                      44
# Turkey                       43
# Slovenia                     39
# Georgia                      37
# England                      36
# Brazil                       31
# Mexico                       31
# Moldova                      30
# Lebanon                      20
# Morocco                      11
# ...

# %%
df.groupby(['country', 'province']).apply(lambda df: df.loc[df['points'].idxmax()])
# Out:
# /tmp/ipykernel_1023/1214096684.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(['country', 'province']).apply(lambda df: df.loc[df['points'].idxmax()])
#                             Unnamed: 0    country  \
# country   province
# Argentina Mendoza Province        8869  Argentina
#           Other                   4633  Argentina
# Armenia   Armenia                 8170    Armenia
# Australia Australia Other        37882  Australia
#           New South Wales        24582  Australia
# ...                                ...        ...
# Uruguay   Juanico                 9133    Uruguay
#           Montevideo             15750    Uruguay
# ...

# %%
df.groupby(['country', 'province'])['price'].agg([len, "min", "max"]).head(30)
# Out:
#                                 len   min    max
# country   province
# Argentina Mendoza Province     1635   4.0  230.0
#           Other                 272   8.0  130.0
# Armenia   Armenia                 1  14.0   14.0
# Australia Australia Other       131   6.0  130.0
#           New South Wales        34   8.0  125.0
#           South Australia       683   7.0  850.0
#           Tasmania               23  16.0  130.0
#           Victoria              159  10.0  350.0
#           Western Australia     147   9.0  250.0
# Austria   Austria                16  11.0  150.0
#           Burgenland            322   7.0  128.0
#           Carnuntum              45  12.0   70.0
#           Eisenberg               7  20.0   69.0
#           Kamptal               213  12.0   99.0
#           Kremstal              180  11.0   84.0
#           Leithaberg             22  17.0  111.0
#           Mittelburgenland       11  11.0   35.0
#           Neusiedlersee           8   9.0   60.0
# ...

# %%
df.groupby(['country', 'province'])['points'].agg(['sum']).sort_values(by='sum', ascending=False)
# Out:
#                                         sum
# country  province
# US       California                 1606069
#          Washington                  383001
# France   Bordeaux                    267150
# Italy    Tuscany                     266132
# US       Oregon                      239669
# ...                                     ...
# Greece   Cyclades                        82
# Moldova  Cahul                           82
# Croatia  Middle and South Dalmatia       82
# Brazil   Serra do Sudeste                82
# Portugal Table wine                      81
#
# [385 rows x 1 columns]

# %%
df['price'] = df['price'].fillna(0)
df
# Out:
#        Unnamed: 0    country  \
# 0               0      Italy
# 1               1   Portugal
# 2               2         US
# 3               3         US
# 4               4         US
# ...           ...        ...
# 65494       65494     France
# 65495       65495  Australia
# 65496       65496         US
# 65497       65497         US
# 65498       65498      Spain
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 65494  Made from young vines from the Vaulorent porti...
# 65495  This is a big, fat, almost sweet-tasting Caber...
# 65496  Much improved over the unripe 2005, Fritz's 20...
# ...
